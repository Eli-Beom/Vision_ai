# %%
# !pip install requests
# Out:
# 'pip'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
pip install opencv-python numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import os

# 현재 디렉토리에 sample.jpg가 있어야 합니다
image_path = "sample.jpg"

# 이미지 파일 존재 여부 확인
if not os.path.exists(image_path):
    print(f"❌ 이미지 파일을 찾을 수 없습니다: {image_path}")
    exit()

# 이미지 로드
image = cv2.imread(image_path)

# BGR → HSV 색상 공간 변환
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 빨간색 범위 지정
lower_red1 = np.array([0, 120, 70])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([170, 120, 70])
upper_red2 = np.array([180, 255, 255])

# 마스크 생성
mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
mask = mask1 + mask2

# 빨간색 영역만 추출
result = cv2.bitwise_and(image, image, mask=mask)

# 결과 출력
cv2.imshow('Original', image)
cv2.imshow('Red Filtered', result)
cv2.waitKey(0)
cv2.destroyAllWindows()
